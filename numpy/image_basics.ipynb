# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# read the file
img = mpimg.imread('./stinkbug.png')

img.shape, img.dtype
# Out:
# ((738, 992, 4), dtype('float32'))

# %%
# plotting

imgplot = plt.imshow(img)

# %%
img[1, :, :].shape
# Out:
# (992, 4)

# %%
img[:, :, 0]
# Out:
# array([[0.42352942, 0.42352942, 0.42352942, ..., 0.4392157 , 0.4392157 ,
#         0.43529412],
#        [0.42352942, 0.42352942, 0.42352942, ..., 0.4392157 , 0.4392157 ,
#         0.4392157 ],
#        [0.42745098, 0.42745098, 0.42745098, ..., 0.44313726, 0.44313726,
#         0.4392157 ],
#        ...,
#        [0.42352942, 0.42352942, 0.42745098, ..., 0.45490196, 0.4509804 ,
#         0.4509804 ],
#        [0.42352942, 0.42352942, 0.42745098, ..., 0.45490196, 0.4509804 ,
#         0.4509804 ],
#        [0.42745098, 0.42745098, 0.42745098, ..., 0.4509804 , 0.4509804 ,
#         0.4509804 ]], dtype=float32)

# %%
# plotting

imgplot = plt.imshow(img[:100, :, :], cmap='hot')
plt.colorbar()

# %%
plt.hist(img[:,:,:].ravel());

# seems we can cut above 0.7, to decrease the size of image

# %%
# plotting

imgplot = plt.imshow(img[:, :, 0]);

# %%
imgplot = plt.imshow(img[:, :, 0], clim=(.0, 0.7));
