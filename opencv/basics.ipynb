# %% [markdown]
# # image operation w. opencv
#
# - read w/ opencv
# - show w/ opencv and matplotlib

# %%
import cv2

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('lena.jpg', cv2.IMREAD_COLOR)
img_gray = cv2.imread('lena.jpg', cv2.IMREAD_GRAYSCALE)
# img_alpha = cv2.imread('lena.jpg', cv2.IMREAD_UNCHANGED)

# %%
type(img), img.shape, img_gray.shape
# Out:
# (numpy.ndarray, (512, 512, 3), (512, 512))

# %%
img[0, :, :]
# Out:
# array([[128, 138, 225],
#        [127, 137, 224],
#        [126, 136, 223],
#        ...,
#        [126, 146, 234],
#        [110, 129, 220],
#        [ 86, 104, 197]], dtype=uint8)

# %%
# show w/ opencv 

cv2.imshow('preview', img)
cv2.waitKey(0)

cv2.destroyWindow('preview')

cv2.waitKey(1)  # it could not close opened window in mac. so i used matplotlib to show
# Out:
# -1

# %%
# show w/ matplotlib 
cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  #opencv reads BGR format default

plt.imshow(img, interpolation = 'bicubic')
# plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
