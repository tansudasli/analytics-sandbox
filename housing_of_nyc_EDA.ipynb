# %% [markdown]
# # Housing - exploratory data analysis (EDA)
#
# NYC housing dataset b/w in 2012-13, seperated by boroughs

# %% [markdown]
# ### The Unseen
#
# - [] ..

# %%
import numpy as np
import pandas as pd
import seaborn as sns

sns.set()

# %%
# read all datasets w/ dates

raw_data = pd.read_csv('dataset/housing/rollingsales_manhattan.csv', parse_dates=['SALE DATE'], infer_datetime_format=True)
raw_data_bronx = pd.read_csv('dataset/housing/rollingsales_bronx.csv', parse_dates=['SALE DATE'], infer_datetime_format=True)
raw_data_brooklyn = pd.read_csv('dataset/housing/rollingsales_brooklyn.csv', parse_dates=['SALE DATE'], infer_datetime_format=True)
raw_data_queens = pd.read_csv('dataset/housing/rollingsales_queens.csv', parse_dates=['SALE DATE'], infer_datetime_format=True)
raw_data_statenisland = pd.read_csv('dataset/housing/rollingsales_statenisland.csv', parse_dates=['SALE DATE'], infer_datetime_format=True)

# conembine all into 1
raw_data = raw_data.append([raw_data_bronx, raw_data_brooklyn, raw_data_queens, raw_data_statenisland])

# change column names
raw_data.columns = ['borough', 'neighborhood', 'building_class_category',
       'tax_class_at_present', 'block', 'lot', 'ease_ment',
       'building_class_at_present', 'address', 'apartment_number',
       'zipcode', 'residential_units', 'commercial_units', 'total_units',
       'land_square_feet', 'gross_square_feet', 'year_built',
       'tax_class_at_sale', 'building_class_at_sale',
       'sale_price', 'sale_date']

raw_data['borough_name'] = raw_data['borough'].map({1:'Manhattan', 3:'Brooklyn', 2:'Bronx', 4:'Queens', 5:'Staten Island'})   

# change column names' order
raw_data = raw_data[['borough', 'borough_name' , 'neighborhood', 'building_class_category',
       'tax_class_at_present', 'tax_class_at_sale', 'block', 'lot', 'ease_ment',
       'building_class_at_present', 'building_class_at_sale', 'address', 'apartment_number',
       'zipcode', 'residential_units', 'commercial_units', 'total_units',
       'land_square_feet', 'gross_square_feet', 'year_built',
       'sale_date', 'sale_price']]

raw_data.head()
# Out:
#    borough borough_name               neighborhood  \
# 0        1    Manhattan
# 1        1    Manhattan
# 2        1    Manhattan
# 3        1    Manhattan
# 4        1    Manhattan
#
#                         building_class_category tax_class_at_present  \
# 0  13  CONDOS - ELEVATOR APARTMENTS
# 1  13  CONDOS - ELEVATOR APARTMENTS
# 2  13  CONDOS - ELEVATOR APARTMENTS
# 3  13  CONDOS - ELEVATOR APARTMENTS
# 4  13  CONDOS - ELEVATOR APARTMENTS
#
#   tax_class_at_sale  block   lot ease_ment building_class_at_present  ...  \
# 0                 2    738  1306                                      ...
# 1                 2    738  1307                                      ...
# 2                 2    738  1308                                      ...
# 3                 2    738  1309                                      ...
# 4                 2    738  1310                                      ...
#
#   apartment_number zipcode residential_units  commercial_units total_units  \
# 0                    10014                 0                 0           0
# 1                    10014                 0                 0           0
# 2                    10014                 0                 0           0
# 3                    10014                 0                 0           0
# 4                    10014                 0                 0           0
#
#   land_square_feet gross_square_feet year_built  sale_date  sale_price
# 0                0                 0          0 2013-05-20  $2,214,693
# 1                0                 0          0 2013-05-16  $1,654,656
# 2                0                 0          0 2013-05-23  $1,069,162
# 3                0                 0          0 2013-05-15  $1,374,637
# 4                0                 0          0 2013-05-13  $1,649,565
#
# [5 rows x 22 columns]

# %%
raw_data.describe(include='all')
# Out:
#              borough borough_name               neighborhood  \
# count   85975.000000        85975                      85975
# unique           NaN            5                        257
# top              NaN    Manhattan  MIDTOWN WEST
# freq             NaN        27395                       6264
# first            NaN          NaN                        NaN
# last             NaN          NaN                        NaN
# mean        2.723606          NaN                        NaN
# std         1.352580          NaN                        NaN
# min         1.000000          NaN                        NaN
# 25%         1.000000          NaN                        NaN
# 50%         3.000000          NaN                        NaN
# 75%         4.000000          NaN                        NaN
# max         5.000000          NaN                        NaN
#
#                              building_class_category tax_class_at_present  \
# count                                          85975                85975
# unique                                            40                   11
# top     01  ONE FAMILY HOMES                                            2
# freq                                           14846                32899
# first                                            NaN                  NaN
# last                                             NaN                  NaN
# mean                                             NaN                  NaN
# std                                              NaN                  NaN
# min                                              NaN                  NaN
# 25%                                              NaN                  NaN
# 50%                                              NaN                  NaN
# 75%                                              NaN                  NaN
# max                                              NaN                  NaN
#
#         tax_class_at_sale         block           lot ease_ment  \
# count             85975.0  85975.000000  85975.000000     85975
# unique                8.0           NaN           NaN         2
# top                   2.0           NaN           NaN
# freq              36960.0           NaN           NaN     85973
# first                 NaN           NaN           NaN       NaN
# last                  NaN           NaN           NaN       NaN
# mean                  NaN   3661.041721    405.420541       NaN
# std                   NaN   3404.028873    652.166743       NaN
# min                   NaN      1.000000      1.000000       NaN
# 25%                   NaN   1052.000000     23.000000       NaN
# 50%                   NaN   2157.000000     51.000000       NaN
# 75%                   NaN   5599.000000   1009.000000       NaN
# max                   NaN  16323.000000   9117.000000       NaN
#
#        building_class_at_present  ... apartment_number       zipcode  \
# count                      85975  ...            85975  85975.000000
# unique                       170  ...             4492           NaN
# top                           D4  ...                            NaN
# freq                       13461  ...            63830           NaN
# first                        NaN  ...              NaN           NaN
# last                         NaN  ...              NaN           NaN
# mean                         NaN  ...              NaN  10758.035254
# std                          NaN  ...              NaN    662.101399
# min                          NaN  ...              NaN      0.000000
# 25%                          NaN  ...              NaN  10028.000000
# 50%                          NaN  ...              NaN  11201.000000
# 75%                          NaN  ...              NaN  11238.000000
# max                          NaN  ...              NaN  11694.000000
#
#        residential_units  commercial_units total_units  land_square_feet  \
# count              85975           85975.0       85975             85975
# unique               261              81.0         273              6245
# top                    0               0.0           1                 0
# freq               24544           55360.0       25991             40340
# first                NaN               NaN         NaN               NaN
# last                 NaN               NaN         NaN               NaN
# mean                 NaN               NaN         NaN               NaN
# std                  NaN               NaN         NaN               NaN
# min                  NaN               NaN         NaN               NaN
# 25%                  NaN               NaN         NaN               NaN
# 50%                  NaN               NaN         NaN               NaN
# 75%                  NaN               NaN         NaN               NaN
# max                  NaN               NaN         NaN               NaN
#
#        gross_square_feet    year_built            sale_date  sale_price
# count              85975  85975.000000                85975       85975
# unique              6539           NaN                  386       10222
# top                    0           NaN  2012-09-27 00:00:00          $0
# freq               42780           NaN                  988       26959
# first                NaN           NaN  2012-08-01 00:00:00         NaN
# last                 NaN           NaN  2013-08-26 00:00:00         NaN
# mean                 NaN   1681.403303                  NaN         NaN
# std                  NaN    670.796500                  NaN         NaN
# min                  NaN      0.000000                  NaN         NaN
# 25%                  NaN   1910.000000                  NaN         NaN
# 50%                  NaN   1931.000000                  NaN         NaN
# 75%                  NaN   1964.000000                  NaN         NaN
# max                  NaN   2013.000000                  NaN         NaN
#
# [13 rows x 22 columns]
